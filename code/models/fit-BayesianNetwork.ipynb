# %% [markdown]
# # Bayesian network model of predator-prey interactions

# %% [markdown]
# ## 1. Description

# %% [markdown]
# Here, I build a Bayesian network implementation of the DAG where there is no feedback between the predator and the prey's behavior within a match.
#
# Our objective is to use causal inference to model the predator-prey interaction as it changes throughout the predator's experience. Our DAG explains how we expect the system to work.

# %% [markdown]
# ## 2. Prepare the session

# %% [markdown]
# I start by importing the librairies that I'll need to build the network.

# %%
# For Bayesian networks
import bnlearn as bn

# For data manipulations
from pathlib import Path
import pandas as pd
import numpy as np

# For ploting
import matplotlib.pyplot as plt
import networkx as nx
import matplotlib as mpl

# %% [markdown]
# ## 3. Import the data

# %% [markdown]
# I import the data to build the network.

# %%
# Specify the parent folder
notebook_dir = Path.cwd()
parent_folder = notebook_dir.parent.parent

# Data path
data_subfolder = "data"
file_name = "FraserFranco-etal-XXXX.csv"

# Full path to data file
file_path = parent_folder / data_subfolder / file_name

# Import dataset
dat = pd.read_csv(file_path, index_col = None)

# %% [markdown]
# ### 3.1 Visualize the data structure

# %% [markdown]
# Let's start by checking the data

# %%
dat.head()
# Out:
#    match_id predator_id xp_level            timestamp game_mode  \
# 0  DHCF1PHC  pred100494   novice  2021-01-02 14:47:16    Online
# 1  BHJFA1I0  pred100494   novice  2021-01-02 14:57:02    Online
# 2  PMM9CDDR  pred100494   novice  2021-01-02 15:08:18    Online
# 3  3NT75SH7  pred100494   novice  2021-01-02 15:30:29    Online
# 4  MNL0ZWA5  pred100494   novice  2021-01-02 15:46:26    Online
#
#                realm_id             environment_id  avatar_id  game_duration  \
# 0        Yamaoka Estate           Family Residence     Wraith     399.848999
# 1  The Macmillan Estate        Groaning Storehouse     Wraith     319.134979
# 2           Silent Hill  Midwich Elementary School     Doctor     687.513123
# 3    Autohaven Wreckers                Blood Lodge   Huntress     528.620361
# 4     Grave of Glenvale           Dead Dawg Saloon  Hillbilly     409.839844
#
#    prey_avg_rank  ...  chase_count  chase_count_success  attacks_count  \
# 0          11.75  ...            5                    1              2
# 1          11.75  ...            8                    0              0
# 2          15.25  ...           19                    0              6
# 3          11.25  ...           11                    0              7
# 4          14.50  ...            4                    0              0
#
#    prey_avg_heal_count  prey_var_heal_count  chase_success_ratio  \
# 0                 1.25             3.583333                  0.2
# 1                 0.00             0.000000                  0.0
# 2                 1.75             0.916667                  0.0
# 3                 1.75             1.583333                  0.0
# 4                 0.00             0.000000                  0.0
#
#    prior_prey_speed  prior_prey_heal  prior_success   time_lag
# 0               NaN              NaN            NaN        NaN
# 1          2.129557             1.25            0.0   9.766133
# 2          2.278671             0.00            0.0  11.271783
# 3          1.962961             1.75            0.0  22.176050
# 4          2.415156             1.75            0.0  15.946550
#
# [5 rows x 30 columns]

# %%
dat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100062 entries, 0 to 100061
# Data columns (total 30 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   match_id               100062 non-null  object
#  1   predator_id            100062 non-null  object
#  2   xp_level               100062 non-null  object
#  3   timestamp              100062 non-null  object
#  4   game_mode              100062 non-null  object
#  5   realm_id               100062 non-null  object
#  6   environment_id         100062 non-null  object
#  7   avatar_id              100062 non-null  object
#  8   game_duration          100062 non-null  float64
#  9   prey_avg_rank          100062 non-null  float64
#  10  total_xp_pred          100062 non-null  int64
#  11  cumul_xp_pred          100062 non-null  int64
#  12  hunting_success        100062 non-null  int64
#  13  points_predator        100062 non-null  int64
#  14  pred_speed             100062 non-null  float64
#  15  prey_avg_speed         100061 non-null  float64
#  16  predicted_mean_speed   100062 non-null  float64
#  17  predicted_sigma_speed  100062 non-null  float64
#  18  cluster                100062 non-null  int64
#  19  hunting_type           100062 non-null  object
#  20  chase_count            100062 non-null  int64
#  21  chase_count_success    100062 non-null  int64
#  22  attacks_count          100062 non-null  int64
#  23  prey_avg_heal_count    100061 non-null  float64
#  24  prey_var_heal_count    99959 non-null   float64
#  25  chase_success_ratio    99912 non-null   float64
#  26  prior_prey_speed       99809 non-null   float64
#  27  prior_prey_heal        99809 non-null   float64
#  28  prior_success          99810 non-null   float64
#  29  time_lag               99810 non-null   float64
# dtypes: float64(13), int64(8), object(9)
# memory usage: 22.9+ MB

# %%
print("Colum names:", dat.columns)
# Out:
# Colum names: Index(['match_id', 'predator_id', 'xp_level', 'timestamp', 'game_mode',
#        'realm_id', 'environment_id', 'avatar_id', 'game_duration',
#        'prey_avg_rank', 'total_xp_pred', 'cumul_xp_pred', 'hunting_success',
#        'points_predator', 'pred_speed', 'prey_avg_speed',
#        'predicted_mean_speed', 'predicted_sigma_speed', 'cluster',
#        'hunting_type', 'chase_count', 'chase_count_success', 'attacks_count',
#        'prey_avg_heal_count', 'prey_var_heal_count', 'chase_success_ratio',
#        'prior_prey_speed', 'prior_prey_heal', 'prior_success', 'time_lag'],
#       dtype='object')

# %% [markdown]
# ## 4. Build the Bayesian network

# %% [markdown]
# Here, I use my expertise and knowledge of the system to build the network. In this manuscript, we suggest a causal model of predator-prey interactions, and we thus build our model based on our beliefs on how the system works.

# %% [markdown]
# ### 4.1 Discretize the continuous variables
#
# I start by discretizing the continuous variables that I'll be using in the network. I will use a quantile-based discretization with 5 bins.

# %%
# Function to create bins
def create_bins(data, column, num_bins = 5):
    data[f"{column}_bin"] = pd.qcut(
        x = data[column], q = num_bins
    )

# Columns to bin
columns_to_bin = [
    "prey_avg_speed",
    "time_lag",
    "prior_prey_speed"
]

# Run the function
for column in columns_to_bin:
    create_bins(dat, column)

# %% [markdown]
# I need to do discretize the variable chase success ratio manually since the pd.cut() function seems to produce bins with negative values, which isn't possible for a ratio.

# %%
column_name = "chase_success_ratio"

# Define the bin edges manually based on the range of the data
min_value = dat[column_name].min()
max_value = dat[column_name].max()
bin_edges = [
    min_value,
    0.2 * (max_value - min_value),
    0.4 * (max_value - min_value),
    0.6 * (max_value - min_value),
    0.8 * (max_value - min_value),
    max_value
]

# Apply manual binning
dat["chase_success_ratio_bin"] = pd.cut(
    x = dat["chase_success_ratio"],
    bins = bin_edges
)

# Check the result
print(dat["chase_success_ratio_bin"].value_counts())
# Out:
# (0.2, 0.4]    44300
# (0.4, 0.6]    25650
# (0.0, 0.2]    20658
# (0.6, 0.8]     5336
# (0.8, 1.0]      692
# Name: chase_success_ratio_bin, dtype: int64

# %% [markdown]
# ### 4.2 Select variables for the Bayesian network
#
# I then subset the variables that I will use for the model.

# %%
# Select relevant variables
selected_variables = [
    "xp_level",
    "time_lag_bin",
    "hunting_type",
    "hunting_success",
    "prey_avg_speed_bin",
    "prior_success",
    "prior_prey_speed_bin",
    "chase_success_ratio_bin"
]

# Subset the data
subset = dat[selected_variables]
subset

# Drop the first row for every player ID (NaN)
subset = subset.dropna()

# Convert success to integer again
subset['prior_success'] = subset['prior_success'].round().astype(int)

subset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 96409 entries, 7 to 100061
# Data columns (total 8 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   xp_level                 96409 non-null  object
#  1   time_lag_bin             96409 non-null  category
#  2   hunting_type             96409 non-null  object
#  3   hunting_success          96409 non-null  int64
#  4   prey_avg_speed_bin       96409 non-null  category
#  5   prior_success            96409 non-null  int64
#  6   prior_prey_speed_bin     96409 non-null  category
#  7   chase_success_ratio_bin  96409 non-null  category
# dtypes: category(4), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
subset.head()
# Out:
#    xp_level          time_lag_bin     hunting_type  hunting_success  \
# 7    novice      (18.035, 25.191]  ambush-flexible                1
# 8    novice  (359.33, 201831.686]  ambush-flexible                0
# 9    novice      (25.191, 359.33]  ambush-flexible                0
# 11   novice      (25.191, 359.33]  ambush-flexible                1
# 15   novice        (5.96, 14.699]  ambush-flexible                0
#
#    prey_avg_speed_bin  prior_success prior_prey_speed_bin  \
# 7       (2.153, 2.35]              0       (2.672, 3.664]
# 8      (0.619, 2.153]              1        (2.153, 2.35]
# 9      (0.619, 2.153]              0       (0.619, 2.153]
# 11      (2.153, 2.35]              0       (2.672, 3.664]
# 15      (2.35, 2.506]              0       (0.619, 2.153]
#
#    chase_success_ratio_bin
# 7               (0.0, 0.2]
# 8               (0.0, 0.2]
# 9               (0.0, 0.2]
# 11              (0.4, 0.6]
# 15              (0.2, 0.4]

# %% [markdown]
# ### 4.2 Build the Bayesian network structure
#
# Here, I build the relationships (edges) between the variables (nodes).
#
# The model goes like this :
#
# **Edges for prior success**
# - prior prey speed --> prior hunting success
#
# **Edges for hunting type**
# - experience --> hunting type
# - prior prey speed --> hunting type
# - prior success --> hunting type
# - time lag --> hunting type
#
# **Edges for chase success ratio**
# - time lag --> chase success ratio
# - experience --> chase success ratio
# - hunting type --> chase success ratio
# - prey speed --> chase success ratio
#
# **Edges for prey speed**
# - hunting type --> prey speed
#
# **Edges for hunting success**
# - chase success ratio --> hunting success
# - hunting type --> hunting success
# - prey speed --> hunting success

# %%
edges = [
    # Edges for prior hunting success
    ("prior_prey_speed_bin", "prior_success"),
    # Edges for hunting type
    ("xp_level", "hunting_type"),
    ("prior_success", "hunting_type"),
    ("time_lag_bin", "hunting_type"),
    ("prior_prey_speed_bin", "hunting_type"),
    # Edges for chase success ratio
    ("time_lag_bin", "chase_success_ratio_bin"),
    ("xp_level", "chase_success_ratio_bin"),
    ("hunting_type", "chase_success_ratio_bin"),
    ("prey_avg_speed_bin", "chase_success_ratio_bin"),
    # Edges for prey speed
    ("hunting_type", "prey_avg_speed_bin"),
    # Edges for hunting success
    ("hunting_type", "hunting_success"),
    ("chase_success_ratio_bin", "hunting_success"),
    ("prey_avg_speed_bin", "hunting_success")
]

# %% [markdown]
# Now I build the dag using the edges object

# %%
DAG = bn.make_DAG(edges)
# Out:
# [bnlearn] >bayes DAG created.

# %% [markdown]
# And I fit the model using the DAG that I constructed. I use the Bayes method.

# %%
DAG = bn.parameter_learning.fit(
    DAG, subset,
    methodtype = "bayes"
)
# Out:
# [bnlearn] >Parameter learning> Computing parameters using [bayes]
# [bnlearn] >CPD of prior_prey_speed_bin:
# +--------------------------------------+----------+
# | prior_prey_speed_bin((0.619, 2.153]) | 0.196768 |
# +--------------------------------------+----------+
# | prior_prey_speed_bin((2.153, 2.35])  | 0.199468 |
# +--------------------------------------+----------+
# | prior_prey_speed_bin((2.35, 2.506])  | 0.200577 |
# +--------------------------------------+----------+
# | prior_prey_speed_bin((2.506, 2.672]) | 0.201573 |
# +--------------------------------------+----------+
# | prior_prey_speed_bin((2.672, 3.664]) | 0.201614 |
# +--------------------------------------+----------+
# [bnlearn] >CPD of prior_success:
# +----------------------+-----+
# | prior_prey_speed_bin | ... |
# +----------------------+-----+
# | prior_success(0)     | ... |
# +----------------------+-----+
# | prior_success(1)     | ... |
# +----------------------+-----+
# | prior_success(2)     | ... |
# +----------------------+-----+
# | prior_success(3)     | ... |
# +----------------------+-----+
# | prior_success(4)     | ... |
# +----------------------+-----+
# [bnlearn] >CPD of xp_level:
# +--------------------+----------+
# | xp_level(advanced) | 0.30594  |
# +--------------------+----------+
# | xp_level(interm)   | 0.463862 |
# +--------------------+----------+
# | xp_level(novice)   | 0.230198 |
# +--------------------+----------+
# [bnlearn] >CPD of hunting_type:
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# [bnlearn] >CPD of time_lag_bin:
# +------------------------------------+----------+
# | time_lag_bin((5.96, 14.699])       | 0.196594 |
# +------------------------------------+----------+
# | time_lag_bin((14.699, 18.035])     | 0.201398 |
# +------------------------------------+----------+
# | time_lag_bin((18.035, 25.191])     | 0.201101 |
# +------------------------------------+----------+
# | time_lag_bin((25.191, 359.33])     | 0.200505 |
# +------------------------------------+----------+
# | time_lag_bin((359.33, 201831.686]) | 0.200402 |
# +------------------------------------+----------+
# [bnlearn] >CPD of chase_success_ratio_bin:
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# [bnlearn] >CPD of prey_avg_speed_bin:
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# | ... |
# +-----+
# [bnlearn] >CPD of hunting_success:
# +-------------------------+-----+
# | chase_success_ratio_bin | ... |
# +-------------------------+-----+
# | hunting_type            | ... |
# +-------------------------+-----+
# | prey_avg_speed_bin      | ... |
# +-------------------------+-----+
# | hunting_success(0)      | ... |
# +-------------------------+-----+
# | hunting_success(1)      | ... |
# +-------------------------+-----+
# | hunting_success(2)      | ... |
# +-------------------------+-----+
# | hunting_success(3)      | ... |
# +-------------------------+-----+
# | hunting_success(4)      | ... |
# +-------------------------+-----+
# [bnlearn] >Compute structure scores for model comparison (higher is better).

# %% [markdown]
# I do the chi-square test to evaluate edge strength

# %%
# Convert to onehot
dfhot, dfnum = bn.df2onehot(subset)

# Compute edge strength with the chi_square test statistic
DAG = bn.independence_test(
    DAG,
    dfnum,
    test = "chi_square",
    prune = False
)
DAG
# Out:
# [df2onehot] >Auto detecting dtypes.
# 100%|██████████| 8/8 [00:07<00:00,  1.03it/s]
# [df2onehot] >Set dtypes in dataframe..
# [df2onehot]: 100%|██████████| 8/8 [00:00<00:00, 39.09it/s]
# [df2onehot] >Total onehot features: 20
# [bnlearn] >Compute edge strength with [chi_square]
# {'model': <pgmpy.models.BayesianNetwork.BayesianNetwork at 0x77641c952980>,
#  'adjmat': target                   prior_prey_speed_bin  prior_success  xp_level  \
#  source
#  prior_prey_speed_bin                    False           True     False
#  prior_success                           False          False     False
#  xp_level                                False          False     False
#  hunting_type                            False          False     False
#  time_lag_bin                            False          False     False
#  chase_success_ratio_bin                 False          False     False
#  prey_avg_speed_bin                      False          False     False
#  hunting_success                         False          False     False
#
#  target                   hunting_type  time_lag_bin  chase_success_ratio_bin  \
#  source
#  prior_prey_speed_bin             True         False                    False
#  prior_success                    True         False                    False
#  xp_level                         True         False                     True
#  hunting_type                    False         False                     True
#  time_lag_bin                     True         False                     True
#  chase_success_ratio_bin         False         False                    False
#  prey_avg_speed_bin              False         False                     True
#  hunting_success                 False         False                    False
#
#  target                   prey_avg_speed_bin  hunting_success
#  source
#  prior_prey_speed_bin                  False            False
#  prior_success                         False            False
#  xp_level                              False            False
#  hunting_type                           True             True
#  time_lag_bin                          False            False
#  chase_success_ratio_bin               False             True
#  prey_avg_speed_bin                    False             True
#  hunting_success                       False            False  ,
#  'config': {'verbose': 3, 'method': 'bayes', 'n_jobs': -1},
#  'model_edges': [('prior_prey_speed_bin', 'prior_success'),
#   ('prior_prey_speed_bin', 'hunting_type'),
#   ('prior_success', 'hunting_type'),
#   ('xp_level', 'hunting_type'),
#   ('xp_level', 'chase_success_ratio_bin'),
#   ('hunting_type', 'chase_success_ratio_bin'),
#   ('hunting_type', 'prey_avg_speed_bin'),
#   ('hunting_type', 'hunting_success'),
#   ('time_lag_bin', 'hunting_type'),
#   ('time_lag_bin', 'chase_success_ratio_bin'),
#   ('chase_success_ratio_bin', 'hunting_success'),
#   ('prey_avg_speed_bin', 'chase_success_ratio_bin'),
#   ('prey_avg_speed_bin', 'hunting_success')],
#  'structure_scores': {'k2': -1065911.21127318,
#   'bic': -1071995.9274186734,
#   'bdeu': -1071604.005465179,
#   'bds': -1071632.424499582},
#  'independence_test':                      source                   target  stat_test       p_value  \
#  0      prior_prey_speed_bin            prior_success      False  1.000000e+00
#  1      prior_prey_speed_bin             hunting_type      False  1.000000e+00
#  2             prior_success             hunting_type       True  1.811858e-47
#  3                  xp_level             hunting_type       True  2.157767e-09
#  4                  xp_level  chase_success_ratio_bin      False  1.000000e+00
#  5              hunting_type  chase_success_ratio_bin      False  1.000000e+00
#  6              hunting_type       prey_avg_speed_bin      False  1.000000e+00
#  7              hunting_type          hunting_success       True  1.953227e-22
#  8              time_lag_bin             hunting_type      False  1.000000e+00
#  9              time_lag_bin  chase_success_ratio_bin      False  1.000000e+00
#  10  chase_success_ratio_bin          hunting_success      False  1.000000e+00
#  11       prey_avg_speed_bin  chase_success_ratio_bin      False  1.000000e+00
#  12       prey_avg_speed_bin          hunting_success      False  1.000000e+00
#
#      chi_square  dof
#  0     0.000000    0
#  1     0.000000    0
#  2   240.457254    8
#  3    46.275957    4
#  4     0.000000    0
#  5     0.000000    0
#  6     0.000000    0
#  7   121.112571    8
#  8     0.000000    0
#  9     0.000000    0
#  10    0.000000    0
#  11    0.000000    0
#  12    0.000000    0  }

# %% [markdown]
# I can check the full Conditional probability distribution

# %%
bn.print_CPD(DAG)
# Out:
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +----+------------+----------+
# |    | xp_level   |        p |
# +====+============+==========+
# |  0 | advanced   | 0.30594  |
# +----+------------+----------+
# |  1 | interm     | 0.463862 |
# +----+------------+----------+
# |  2 | novice     | 0.230198 |
# +----+------------+----------+
# CPD of xp_level:
# +--------------------+----------+
# | xp_level(advanced) | 0.30594  |
# +--------------------+----------+
# | xp_level(interm)   | 0.463862 |
# +--------------------+----------+
# | xp_level(novice)   | 0.230198 |
# +--------------------+----------+
# [bnlearn] >Warning: variable(s) [None] does not exists in DAG.
# [bnlearn] >Data is stored in [query.df]
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |      | hunting_type              | prior_prey_speed_bin   |   prior_success | time_lag_bin         | xp_level   |        p |
# +======+===========================+========================+=================+======================+============+==========+
# |    0 | ambush-flexible           | (0.619, 2.153]         |               0 | (5.96, 14.699]       | advanced   | 0.627598 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |    1 | ambush-flexible           | (0.619, 2.153]         |               0 | (5.96, 14.699]       | interm     | 0.507796 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |    2 | ambush-flexible           | (0.619, 2.153]         |               0 | (5.96, 14.699]       | novice     | 0.370265 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |    3 | ambush-flexible           | (0.619, 2.153]         |               0 | (14.699, 18.035]     | advanced   | 0.538381 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |    4 | ambush-flexible           | (0.619, 2.153]         |               0 | (14.699, 18.035]     | interm     | 0.502884 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |    5 | ambush-flexible           | (0.619, 2.153]         |               0 | (14.699, 18.035]     | novice     | 0.310017 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |    6 | ambush-flexible           | (0.619, 2.153]         |               0 | (18.035, 25.191]     | advanced   | 0.629053 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |    7 | ambush-flexible           | (0.619, 2.153]         |               0 | (18.035, 25.191]     | interm     | 0.526016 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |    8 | ambush-flexible           | (0.619, 2.153]         |               0 | (18.035, 25.191]     | novice     | 0.415184 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |    9 | ambush-flexible           | (0.619, 2.153]         |               0 | (25.191, 359.33]     | advanced   | 0.516092 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |   10 | ambush-flexible           | (0.619, 2.153]         |               0 | (25.191, 359.33]     | interm     | 0.560194 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |   11 | ambush-flexible           | (0.619, 2.153]         |               0 | (25.191, 359.33]     | novice     | 0.409899 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |   12 | ambush-flexible           | (0.619, 2.153]         |               0 | (359.33, 201831.686] | advanced   | 0.474422 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |   13 | ambush-flexible           | (0.619, 2.153]         |               0 | (359.33, 201831.686] | interm     | 0.532175 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |   14 | ambush-flexible           | (0.619, 2.153]         |               0 | (359.33, 201831.686] | novice     | 0.335408 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |   15 | ambush-flexible           | (0.619, 2.153]         |               1 | (5.96, 14.699]       | advanced   | 0.353741 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |   16 | ambush-flexible           | (0.619, 2.153]         |               1 | (5.96, 14.699]       | interm     | 0.358543 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |   17 | ambush-flexible           | (0.619, 2.153]         |               1 | (5.96, 14.699]       | novice     | 0.238796 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |
|
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |  162 | ambush-flexible           | (2.35, 2.506]          |               0 | (359.33, 201831.686] | advanced   | 0.355367 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |  163 | ambush-flexible           | (2.35, 2.506]          |               0 | (359.33, 201831.686] | interm     | 0.254264 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |  164 | ambush-flexible           | (2.35, 2.506]          |               0 | (359.33, 201831.686] | novice     | 0.28033  |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |  165 | ambush-flexible           | (2.35, 2.506]          |               1 | (5.96, 14.699]       | advanced   | 0.260063 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |  166 | ambush-flexible           | (2.35, 2.506]          |               1 | (5.96, 14.699]       | interm     | 0.25112  |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |  167 | ambush-flexible           | (2.35, 2.506]          |               1 | (5.96, 14.699]       | novice     | 0.191288 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |  168 | ambush-flexible           | (2.35, 2.506]          |               1 | (14.699, 18.035]     | advanced   | 0.239326 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |  169 | ambush-flexible           | (2.35, 2.506]          |               1 | (14.699, 18.035]     | interm     | 0.214048 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |  170 | ambush-flexible           | (2.35, 2.506]          |               1 | (14.699, 18.035]     | novice     | 0.18071  |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |  171 | ambush-flexible           | (2.35, 2.506]          |               1 | (18.035, 25.191]     | advanced   | 0.208972 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |  172 | ambush-flexible           | (2.35, 2.506]          |               1 | (18.035, 25.191]     | interm     | 0.2073   |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |  173 | ambush-flexible           | (2.35, 2.506]          |               1 | (18.035, 25.191]     | novice     | 0.221161 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |  174 | ambush-flexible           | (2.35, 2.506]          |               1 | (25.191, 359.33]     | advanced   | 0.238188 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |  175 | ambush-flexible           | (2.35, 2.506]          |               1 | (25.191, 359.33]     | interm     | 0.303536 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |  176 | ambush-flexible           | (2.35, 2.506]          |               1 | (25.191, 359.33]     | novice     | 0.285606 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |  177 | ambush-flexible           | (2.35, 2.506]          |               1 | (359.33, 201831.686] | advanced   | 0.226621 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |  178 | ambush-flexible           | (2.35, 2.506]          |               1 | (359.33, 201831.686] | interm     | 0.206215 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |  179 | ambush-flexible           | (2.35, 2.506]          |               1 | (359.33, 201831.686] | novice     | 0.169271 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |  180 | ambush-flexible           | (2.35, 2.506]          |               2 | (5.96, 14.699]       | advanced   | 0.212644 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |  181 | ambush-flexible           | (2.35, 2.506]          |               2 | (5.96, 14.699]       | interm     | 0.254508 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |  182 | ambush-flexible           | (2.35, 2.506]          |               2 | (5.96, 14.699]       | novice     | 0.19602  |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |  183 | ambush-flexible           | (2.35, 2.506]          |               2 | (14.699, 18.035]     | advanced   | 0.193473 |
# +------+---------------------------+------------------------+-----------------+----------------------+------------+----------+
# |  184 | ambush-flexible           | (2.35, 2.506]          |               2 | (14.699, 18.035]     | interm     | 0.25514  |
# ...
# (hunting_success ⟂ prior_prey_speed_bin, prior_success | hunting_type, time_lag_bin, xp_level)
# (hunting_success ⟂ prior_prey_speed_bin, prior_success | hunting_type, time_lag_bin, prey_avg_speed_bin, xp_level)
# (hunting_success ⟂ time_lag_bin, prior_prey_speed_bin, prior_success | hunting_type, prey_avg_speed_bin, xp_level, chase_success_ratio_bin)
# (hunting_success ⟂ xp_level, prior_prey_speed_bin, prior_success | hunting_type, time_lag_bin, prey_avg_speed_bin, chase_success_ratio_bin)
# (hunting_success ⟂ time_lag_bin, xp_level, prior_success | hunting_type, prey_avg_speed_bin, prior_prey_speed_bin, chase_success_ratio_bin)
# (hunting_success ⟂ time_lag_bin, xp_level, prior_prey_speed_bin | hunting_type, prey_avg_speed_bin, prior_success, chase_success_ratio_bin)
# (hunting_success ⟂ prior_success | hunting_type, time_lag_bin, xp_level, prior_prey_speed_bin)
# (hunting_success ⟂ prior_prey_speed_bin | hunting_type, time_lag_bin, xp_level, prior_success)
# (hunting_success ⟂ prior_prey_speed_bin, prior_success | hunting_type, time_lag_bin, xp_level, chase_success_ratio_bin)
# (hunting_success ⟂ prior_success | hunting_type, time_lag_bin, prior_prey_speed_bin, prey_avg_speed_bin, xp_level)
# (hunting_success ⟂ prior_prey_speed_bin | hunting_type, time_lag_bin, prior_success, prey_avg_speed_bin, xp_level)
# (hunting_success ⟂ prior_prey_speed_bin, prior_success | hunting_type, time_lag_bin, prey_avg_speed_bin, xp_level, chase_success_ratio_bin)
# (hunting_success ⟂ time_lag_bin, prior_success | hunting_type, prior_prey_speed_bin, prey_avg_speed_bin, xp_level, chase_success_ratio_bin)
# (hunting_success ⟂ time_lag_bin, prior_prey_speed_bin | hunting_type, prior_success, prey_avg_speed_bin, xp_level, chase_success_ratio_bin)
# (hunting_success ⟂ xp_level, prior_success | hunting_type, time_lag_bin, prior_prey_speed_bin, prey_avg_speed_bin, chase_success_ratio_bin)
# (hunting_success ⟂ xp_level, prior_prey_speed_bin | hunting_type, time_lag_bin, prior_success, prey_avg_speed_bin, chase_success_ratio_bin)
# (hunting_success ⟂ time_lag_bin, xp_level | hunting_type, prior_prey_speed_bin, prior_success, prey_avg_speed_bin, chase_success_ratio_bin)
# (hunting_success ⟂ prior_success | hunting_type, time_lag_bin, prior_prey_speed_bin, xp_level, chase_success_ratio_bin)
# (hunting_success ⟂ prior_prey_speed_bin | hunting_type, time_lag_bin, prior_success, xp_level, chase_success_ratio_bin)
# (hunting_success ⟂ prior_success | hunting_type, time_lag_bin, prior_prey_speed_bin, prey_avg_speed_bin, xp_level, chase_success_ratio_bin)
# (hunting_success ⟂ prior_prey_speed_bin | hunting_type, time_lag_bin, prior_success, prey_avg_speed_bin, xp_level, chase_success_ratio_bin)
# (hunting_success ⟂ time_lag_bin | hunting_type, prior_prey_speed_bin, prior_success, prey_avg_speed_bin, xp_level, chase_success_ratio_bin)
# (hunting_success ⟂ xp_level | hunting_type, time_lag_bin, prior_prey_speed_bin, prior_success, prey_avg_speed_bin, chase_success_ratio_bin)
# (prey_avg_speed_bin ⟂ time_lag_bin, xp_level, prior_prey_speed_bin, prior_success | hunting_type)
# (prey_avg_speed_bin ⟂ time_lag_bin, prior_prey_speed_bin, prior_success | hunting_type, xp_level)
# (prey_avg_speed_bin ⟂ xp_level, prior_prey_speed_bin, prior_success | hunting_type, time_lag_bin)
# (prey_avg_speed_bin ⟂ time_lag_bin, xp_level, prior_success | hunting_type, prior_prey_speed_bin)
# (prey_avg_speed_bin ⟂ time_lag_bin, xp_level, prior_prey_speed_bin | hunting_type, prior_success)
# (prey_avg_speed_bin ⟂ prior_prey_speed_bin, prior_success | hunting_type, time_lag_bin, xp_level)
# (prey_avg_speed_bin ⟂ time_lag_bin, prior_success | hunting_type, xp_level, prior_prey_speed_bin)
# (prey_avg_speed_bin ⟂ time_lag_bin, prior_prey_speed_bin | hunting_type, xp_level, prior_success)
# (prey_avg_speed_bin ⟂ xp_level, prior_success | hunting_type, time_lag_bin, prior_prey_speed_bin)
# (prey_avg_speed_bin ⟂ xp_level, prior_prey_speed_bin | hunting_type, time_lag_bin, prior_success)
# (prey_avg_speed_bin ⟂ time_lag_bin, xp_level | hunting_type, prior_prey_speed_bin, prior_success)
# (prey_avg_speed_bin ⟂ prior_prey_speed_bin, prior_success | hunting_type, time_lag_bin, xp_level, hunting_success)
# (prey_avg_speed_bin ⟂ prior_success | hunting_type, time_lag_bin, xp_level, prior_prey_speed_bin)
# (prey_avg_speed_bin ⟂ prior_prey_speed_bin | hunting_type, time_lag_bin, xp_level, prior_success)
# (prey_avg_speed_bin ⟂ prior_prey_speed_bin, prior_success | hunting_type, time_lag_bin, xp_level, chase_success_ratio_bin)
# (prey_avg_speed_bin ⟂ time_lag_bin | hunting_type, xp_level, prior_prey_speed_bin, prior_success)
# (prey_avg_speed_bin ⟂ xp_level | hunting_type, time_lag_bin, prior_prey_speed_bin, prior_success)
# (prey_avg_speed_bin ⟂ prior_success | hunting_type, time_lag_bin, prior_prey_speed_bin, hunting_success, xp_level)
# (prey_avg_speed_bin ⟂ prior_prey_speed_bin | hunting_type, time_lag_bin, hunting_success, prior_success, xp_level)
# (prey_avg_speed_bin ⟂ prior_prey_speed_bin, prior_success | hunting_type, time_lag_bin, hunting_success, xp_level, chase_success_ratio_bin)
# (prey_avg_speed_bin ⟂ prior_success | hunting_type, time_lag_bin, prior_prey_speed_bin, xp_level, chase_success_ratio_bin)
# (prey_avg_speed_bin ⟂ prior_prey_speed_bin | hunting_type, time_lag_bin, prior_success, xp_level, chase_success_ratio_bin)
# (prey_avg_speed_bin ⟂ prior_success | hunting_type, time_lag_bin, prior_prey_speed_bin, hunting_success, xp_level, chase_success_ratio_bin)
# (prey_avg_speed_bin ⟂ prior_prey_speed_bin | hunting_type, time_lag_bin, hunting_success, prior_success, xp_level, chase_success_ratio_bin)
# (xp_level ⟂ time_lag_bin, prior_prey_speed_bin, prior_success)
# (xp_level ⟂ prey_avg_speed_bin | hunting_type)
# (xp_level ⟂ prior_prey_speed_bin, prior_success | time_lag_bin)
# (xp_level ⟂ time_lag_bin, prior_success | prior_prey_speed_bin)
# (xp_level ⟂ time_lag_bin, prior_prey_speed_bin | prior_success)
# (xp_level ⟂ prey_avg_speed_bin | hunting_type, time_lag_bin)
# (xp_level ⟂ prey_avg_speed_bin | hunting_type, prior_prey_speed_bin)
# (xp_level ⟂ prey_avg_speed_bin | hunting_type, prior_success)
# (xp_level ⟂ prior_success | time_lag_bin, prior_prey_speed_bin)
# (xp_level ⟂ prior_prey_speed_bin | time_lag_bin, prior_success)
# (xp_level ⟂ time_lag_bin | prior_prey_speed_bin, prior_success)
# (xp_level ⟂ hunting_success | hunting_type, prey_avg_speed_bin, chase_success_ratio_bin)
# (xp_level ⟂ prey_avg_speed_bin | hunting_type, time_lag_bin, prior_prey_speed_bin)
# (xp_level ⟂ prey_avg_speed_bin | hunting_type, time_lag_bin, prior_success)
# (xp_level ⟂ prey_avg_speed_bin | hunting_type, prior_prey_speed_bin, prior_success)
# (xp_level ⟂ hunting_success | hunting_type, time_lag_bin, prey_avg_speed_bin, chase_success_ratio_bin)
# (xp_level ⟂ hunting_success | hunting_type, prey_avg_speed_bin, prior_prey_speed_bin, chase_success_ratio_bin)
# (xp_level ⟂ hunting_success | hunting_type, prey_avg_speed_bin, prior_success, chase_success_ratio_bin)
# (xp_level ⟂ prey_avg_speed_bin | hunting_type, time_lag_bin, prior_prey_speed_bin, prior_success)
# (xp_level ⟂ hunting_success | hunting_type, time_lag_bin, prior_prey_speed_bin, prey_avg_speed_bin, chase_success_ratio_bin)
# (xp_level ⟂ hunting_success | hunting_type, time_lag_bin, prior_success, prey_avg_speed_bin, chase_success_ratio_bin)
# (xp_level ⟂ hunting_success | hunting_type, prior_prey_speed_bin, prior_success, prey_avg_speed_bin, chase_success_ratio_bin)
# (xp_level ⟂ hunting_success | hunting_type, time_lag_bin, prior_prey_speed_bin, prior_success, prey_avg_speed_bin, chase_success_ratio_bin)
# (chase_success_ratio_bin ⟂ prior_prey_speed_bin, prior_success | hunting_type, time_lag_bin, xp_level)
# (chase_success_ratio_bin ⟂ prior_prey_speed_bin, prior_success | hunting_type, time_lag_bin, xp_level, hunting_success)
# (chase_success_ratio_bin ⟂ prior_prey_speed_bin, prior_success | hunting_type, time_lag_bin, prey_avg_speed_bin, xp_level)
# (chase_success_ratio_bin ⟂ prior_success | hunting_type, time_lag_bin, xp_level, prior_prey_speed_bin)
# (chase_success_ratio_bin ⟂ prior_prey_speed_bin | hunting_type, time_lag_bin, xp_level, prior_success)
# (chase_success_ratio_bin ⟂ prior_prey_speed_bin, prior_success | hunting_type, time_lag_bin, hunting_success, prey_avg_speed_bin, xp_level)
# (chase_success_ratio_bin ⟂ prior_success | hunting_type, time_lag_bin, prior_prey_speed_bin, hunting_success, xp_level)
# (chase_success_ratio_bin ⟂ prior_prey_speed_bin | hunting_type, time_lag_bin, hunting_success, prior_success, xp_level)
# (chase_success_ratio_bin ⟂ prior_success | hunting_type, time_lag_bin, prior_prey_speed_bin, prey_avg_speed_bin, xp_level)
# (chase_success_ratio_bin ⟂ prior_prey_speed_bin | hunting_type, time_lag_bin, prior_success, prey_avg_speed_bin, xp_level)
# (chase_success_ratio_bin ⟂ prior_success | hunting_type, time_lag_bin, hunting_success, prior_prey_speed_bin, prey_avg_speed_bin, xp_level)
# (chase_success_ratio_bin ⟂ prior_prey_speed_bin | hunting_type, time_lag_bin, hunting_success, prior_success, prey_avg_speed_bin, xp_level)
# [bnlearn] >Nodes: ['xp_level', 'hunting_type', 'prior_success', 'time_lag_bin', 'prior_prey_speed_bin', 'chase_success_ratio_bin', 'prey_avg_speed_bin', 'hunting_success']
# [bnlearn] >Edges: [('xp_level', 'hunting_type'), ('xp_level', 'chase_success_ratio_bin'), ('hunting_type', 'chase_success_ratio_bin'), ('hunting_type', 'prey_avg_speed_bin'), ('hunting_type', 'hunting_success'), ('prior_success', 'hunting_type'), ('time_lag_bin', 'hunting_type'), ('time_lag_bin', 'chase_success_ratio_bin'), ('prior_prey_speed_bin', 'hunting_type'), ('chase_success_ratio_bin', 'hunting_success'), ('prey_avg_speed_bin', 'chase_success_ratio_bin'), ('prey_avg_speed_bin', 'hunting_success')]
# {'xp_level':    xp_level         p
#  0  advanced  0.305940
#  1    interm  0.463862
#  2    novice  0.230198,
#  'hunting_type':                    hunting_type prior_prey_speed_bin  prior_success  \
#  0               ambush-flexible       (0.619, 2.153]              0
#  1               ambush-flexible       (0.619, 2.153]              0
#  2               ambush-flexible       (0.619, 2.153]              0
#  3               ambush-flexible       (0.619, 2.153]              0
#  4               ambush-flexible       (0.619, 2.153]              0
#  ...                         ...                  ...            ...
#  1120  intercepting-intermediate       (2.672, 3.664]              4
#  1121  intercepting-intermediate       (2.672, 3.664]              4
#  1122  intercepting-intermediate       (2.672, 3.664]              4
#  1123  intercepting-intermediate       (2.672, 3.664]              4
#  1124  intercepting-intermediate       (2.672, 3.664]              4
#
#                time_lag_bin  xp_level         p
#  0           (5.96, 14.699]  advanced  0.627598
#  1           (5.96, 14.699]    interm  0.507796
#  2           (5.96, 14.699]    novice  0.370265
#  3         (14.699, 18.035]  advanced  0.538381
#  4         (14.699, 18.035]    interm  0.502884
#  ...                    ...       ...       ...
#  1120      (25.191, 359.33]    interm  0.384971
#  1121      (25.191, 359.33]    novice  0.351433
#  1122  (359.33, 201831.686]  advanced  0.311846
#  1123  (359.33, 201831.686]    interm  0.288917
#  1124  (359.33, 201831.686]    novice  0.370031
#
#  [1125 rows x 6 columns],
#  'prior_success':    prior_success         p
#  0              0  0.209549
#  1              1  0.190609
#  2              2  0.154606
#  3              3  0.192539
#  4              4  0.252697,
#  'time_lag_bin':            time_lag_bin         p
#  0        (5.96, 14.699]  0.196594
#  1      (14.699, 18.035]  0.201398
#  2      (18.035, 25.191]  0.201101
#  3      (25.191, 359.33]  0.200505
#  4  (359.33, 201831.686]  0.200402,
#  'prior_prey_speed_bin':   prior_prey_speed_bin         p
#  0       (0.619, 2.153]  0.196768
#  1        (2.153, 2.35]  0.199468
#  2        (2.35, 2.506]  0.200577
#  3       (2.506, 2.672]  0.201573
#  4       (2.672, 3.664]  0.201614,
#  'chase_success_ratio_bin':      chase_success_ratio_bin               hunting_type prey_avg_speed_bin  \
#  0                 (0.0, 0.2]            ambush-flexible     (0.619, 2.153]
#  1                 (0.0, 0.2]            ambush-flexible     (0.619, 2.153]
#  2                 (0.0, 0.2]            ambush-flexible     (0.619, 2.153]
#  3                 (0.0, 0.2]            ambush-flexible     (0.619, 2.153]
#  4                 (0.0, 0.2]            ambush-flexible     (0.619, 2.153]
#  ...                      ...                        ...                ...
#  1120              (0.8, 1.0]  intercepting-intermediate     (2.671, 3.664]
#  1121              (0.8, 1.0]  intercepting-intermediate     (2.671, 3.664]
#  1122              (0.8, 1.0]  intercepting-intermediate     (2.671, 3.664]
#  1123              (0.8, 1.0]  intercepting-intermediate     (2.671, 3.664]
#  1124              (0.8, 1.0]  intercepting-intermediate     (2.671, 3.664]
#
#                time_lag_bin  xp_level         p
#  0           (5.96, 14.699]  advanced  0.201838
#  1           (5.96, 14.699]    interm  0.250505
#  2           (5.96, 14.699]    novice  0.262640
#  3         (14.699, 18.035]  advanced  0.164452
#  4         (14.699, 18.035]    interm  0.189442
#  ...                    ...       ...       ...
#  1120      (25.191, 359.33]    interm  0.002904
#  1121      (25.191, 359.33]    novice  0.003636
#  1122  (359.33, 201831.686]  advanced  0.001952
#  1123  (359.33, 201831.686]    interm  0.001437
#  1124  (359.33, 201831.686]    novice  0.004846
#
#  [1125 rows x 6 columns],
#  'prey_avg_speed_bin':    prey_avg_speed_bin               hunting_type         p
#  0      (0.619, 2.153]            ambush-flexible  0.259361
#  1      (0.619, 2.153]       cursorial-specialist  0.159528
#  2      (0.619, 2.153]  intercepting-intermediate  0.203452
#  3       (2.153, 2.35]            ambush-flexible  0.213565
#  4       (2.153, 2.35]       cursorial-specialist  0.186649
#  5       (2.153, 2.35]  intercepting-intermediate  0.206917
#  6       (2.35, 2.506]            ambush-flexible  0.194517
#  7       (2.35, 2.506]       cursorial-specialist  0.205015
#  8       (2.35, 2.506]  intercepting-intermediate  0.200535
#  9      (2.506, 2.671]            ambush-flexible  0.173778
#  10     (2.506, 2.671]       cursorial-specialist  0.216601
#  11     (2.506, 2.671]  intercepting-intermediate  0.201234
#  12     (2.671, 3.664]            ambush-flexible  0.158779
#  13     (2.671, 3.664]       cursorial-specialist  0.232207
#  14     (2.671, 3.664]  intercepting-intermediate  0.187862,
#  'hunting_success':      hunting_success chase_success_ratio_bin               hunting_type  \
#  0                  0              (0.0, 0.2]            ambush-flexible
#  1                  0              (0.0, 0.2]            ambush-flexible
#  2                  0              (0.0, 0.2]            ambush-flexible
#  3                  0              (0.0, 0.2]            ambush-flexible
#  4                  0              (0.0, 0.2]            ambush-flexible
#  ..               ...                     ...                        ...
#  370                4              (0.8, 1.0]  intercepting-intermediate
#  371                4              (0.8, 1.0]  intercepting-intermediate
#  372                4              (0.8, 1.0]  intercepting-intermediate
#  373                4              (0.8, 1.0]  intercepting-intermediate
#  374                4              (0.8, 1.0]  intercepting-intermediate
#
#      prey_avg_speed_bin         p
#  0       (0.619, 2.153]  0.558054
#  1        (2.153, 2.35]  0.542746
#  2        (2.35, 2.506]  0.532950
#  3       (2.506, 2.671]  0.564821
#  4       (2.671, 3.664]  0.623929
#  ..                 ...       ...
#  370     (0.619, 2.153]  0.628885
#  371      (2.153, 2.35]  0.593103
#  372      (2.35, 2.506]  0.391753
#  373     (2.506, 2.671]  0.302632
#  374     (2.671, 3.664]  0.269231
#
#  [375 rows x 5 columns]}

# %% [markdown]
# Testing a plot

# %%
# Get edge properties from the DAG
edge_properties = bn.get_edge_properties(DAG)

# Create a directed graph
G = nx.DiGraph()

# Add edges with sizes based on chi-square test results
for edge, properties in edge_properties.items():
    strength = properties.get('weight', 0)  # Use 'weight' as the correct attribute name
    G.add_edge(*edge, weight=strength)

# Round the edge weights to 1 digit
rounded_edge_labels = {(u, v): round(properties['weight'], 1) for (u, v), properties in edge_properties.items()}

# Draw the graph with rounded edge sizes and without weight labels
pos = nx.spring_layout(G)  # You can choose a different layout if needed
nx.draw(
    G, pos, with_labels=True, node_size=700,
    node_color="skyblue", font_size=10, font_color="black",
    width=[G[u][v]['weight'] for u, v in G.edges()]
    #width = [2*G[u][v]['weight'] for u, v in G.edges()]
    )

plt.show()
# Out:
# [bnlearn]> Set edge weights based on the [chi_square] test statistic.
# [bnlearn] >Converting source-target into adjacency matrix..
# [bnlearn] >Making the matrix symmetric..
# [bnlearn] >Set edge properties.

# %%
# Get edge properties from the DAG
edge_properties = bn.get_edge_properties(DAG)

# Create a directed graph
G = nx.DiGraph()

# Add edges with weights based on chi-square test results
for edge, properties in edge_properties.items():
    strength = properties.get("weight", 0)
    G.add_edge(*edge, weight = strength)

# Manually specify node names
node_mapping = {
    "hunting_type": "Hunting\ntype",
    "hunting_success": "Hunting\nsuccess",
    "prey_avg_speed_bin": "Prey speed",
    "prior_prey_speed_bin": "Prior\nprey speed",
    "prior_success": "Prior\nhunting\nsuccess",
    "chase_success_ratio_bin": "Chase\nsuccess\nratio",
    "time_lag_bin": "Time\nlag",
    "xp_level": "Experience\nlevel"
}
G = nx.relabel_nodes(G, node_mapping)

# Define positions for the nodes
pos = {
    "Experience\nlevel": (0.5, 0),
    "Prior\nhunting\nsuccess": (0.8, 0.005),
    "Prior\nprey speed": (1.2, 0.005),
    "Time\nlag": (0.5, -0.0055),
    "Hunting\ntype": (1, 0),
    "Prey speed": (1.5, 0),
    "Chase\nsuccess\nratio": (1, -0.0055),
    "Hunting\nsuccess": (1.25, -0.01),
}

# Set a fixed larger size for nodes
node_size = 5000
node_sizes = [node_size for _ in range(len(G))]

# Define edge colors and transparency
M = G.number_of_edges()
edge_colors = [
    properties["weight"] for u, v,
    properties in G.edges(data = True)
]
edge_alphas = [(5 + i) / (M + 4) for i in range(M)]

# Use viridis colormap
cmap = plt.cm.viridis

# Plot size
plt.figure(figsize = (15, 10))

# Draw the DAG
nodes = nx.draw_networkx_nodes(
    G,
    pos,
    node_size = node_sizes,
    node_color = "indigo",
    edgecolors = "black"
)

edges = nx.draw_networkx_edges(
    G,
    pos,
    node_size = node_sizes,
    arrowstyle = "->",
    arrowsize = 20,
    edge_color = edge_colors,
    edge_cmap = cmap,
    width = 2,
)

# set alpha value for each edge
#for i in range(M):
#    edges[i].set_alpha(edge_alphas[i])

pc = mpl.collections.PatchCollection(edges, cmap = cmap)
pc.set_array(edge_colors)

# Display node labels
node_labels = nx.draw_networkx_labels(
    G, pos,
    font_size = 10,
    font_weight = "bold",
    font_color = "white"
)

# Display the figure
ax = plt.gca()
ax.set_axis_off()
plt.colorbar(pc, ax = ax, label = "Edge strength")
plt.show()
# Out:
# [bnlearn]> Set edge weights based on the [chi_square] test statistic.
# [bnlearn] >Converting source-target into adjacency matrix..
# [bnlearn] >Making the matrix symmetric..
# [bnlearn] >Set edge properties.
